# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import openpyxl

# %%
file_path = r'E:/Magnetometry/mag1.xlsx'
data = pd.read_excel(file_path)

# %%
x = data['x']
y = data['y']
z = data['z']
mag = data['n']

# %%
grid_x, grid_y = np.meshgrid(np.linspace(min(x), max(x), 100), np.linspace(min(y), max(y), 100))

# %%
grid_mag = griddata((x, y), mag, (grid_x, grid_y), method='cubic')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='viridis')
plt.colorbar(label='Magnetic Field (nT)')

# %%
file_path = r'E:/Magnetometry/mag2.xlsx'
data = pd.read_excel(file_path)

# %%
x = data['x']
y = data['y']
z = data['z']
mag = data['n']

# %%
grid_x, grid_y = np.meshgrid(np.linspace(min(x), max(x), 100), np.linspace(min(y), max(y), 100))

# %%
grid_mag = griddata((x, y), mag, (grid_x, grid_y), method='cubic')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='viridis')
plt.colorbar(label='Magnetic Field (nT)')

# %%
file_path = r'E:/Magnetometry/mag2+1.xlsx'
data = pd.read_excel(file_path)

# %%
x = data['x']
y = data['y']
z = data['z']
mag = data['n']

# %%
grid_x, grid_y = np.meshgrid(np.linspace(min(x), max(x), 100), np.linspace(min(y), max(y), 100))

# %%
grid_mag = griddata((x, y), mag, (grid_x, grid_y), method='cubic')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='viridis')
plt.colorbar(label='Magnetic Field (nT)')

# %%
mag.max()
# Out:
# 49164.84

# %%
mag.min()
# Out:
# 48217.61

# %%
grid_mag = griddata((x, y), mag, (grid_x, grid_y), method='linear')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='viridis')
plt.colorbar(label='Magnetic Field (nT)')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='jet')
plt.colorbar(label='Magnetic Field (nT)')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(grid_mag, extent=(min(x), max(x), min(y), max(y)), origin='lower', cmap='coolwarm')
plt.colorbar(label='Magnetic Field (nT)')
